# %% [markdown]
# # 脑启发AI系统用户界面演示
#
# 这个notebook演示了如何使用脑启发AI系统的交互式用户界面。
#
# ## 功能概览
# - 🧠 实时系统状态监控
# - 🎯 交互式模型训练
# - 📊 性能监控仪表板
# - 🔧 系统架构可视化
# - 📚 交互式教程和文档
#
# 让我们开始探索这些功能！

# %%
# 导入必要的库
import sys
sys.path.append('/workspace/brain-inspired-ai/ui')

from jupyter_integration import (
    notebook_ui,
    show_brain_dashboard,
    show_training_console,
    show_performance_dashboard,
    show_system_diagram,
    create_brain_monitor_widget,
    create_training_widget,
    create_performance_chart
)

print("✅ 脑启发AI系统界面库已加载")

# %% [markdown]
# ## 1. 系统概览仪表板
#
# 首先让我们查看系统的整体状态仪表板，它显示了关键的系统指标：
# - CPU和内存使用率
# - 大脑活跃区域状态
# - 意识水平
# - 实时数据更新

# %%
# 显示系统概览仪表板
show_brain_dashboard()

# %% [markdown]
# ## 2. 系统架构图
#
# 查看大脑启发AI系统的架构，了解各个组件之间的关系：
# - 6个主要大脑区域
# - 区域间的连接关系
# - 功能描述
# - 交互式区域详情

# %%
# 显示系统架构图
show_system_diagram()

# %% [markdown]
# ## 3. 交互式训练界面
#
# 使用训练控制台来管理和监控模型训练过程：
# - 调整训练参数
# - 实时监控损失和准确率
# - 训练进度可视化
# - 开始/暂停/停止控制

# %%
# 显示训练控制台
show_training_console()

# %% [markdown]
# ## 4. 性能监控仪表板
#
# 实时监控系统性能指标：
# - CPU使用率
# - 内存使用情况
# - 网络延迟
# - 资源使用趋势

# %%
# 显示性能监控仪表板
show_performance_dashboard()

# %% [markdown]
# ## 5. 交互式小部件
#
# 除了嵌入的HTML界面，我们还提供了基于ipywidgets的交互式小部件。

# %%
# 创建大脑状态监控小部件
try:
    brain_widget = create_brain_monitor_widget()
    display(brain_widget)
except ImportError:
    print("❌ ipywidgets未安装，请运行: pip install ipywidgets")

# %%
# 创建训练控制小部件
try:
    training_widget = create_training_widget()
    display(training_widget)
except ImportError:
    print("❌ ipywidgets未安装，请运行: pip install ipywidgets")

# %% [markdown]
# ## 6. 性能数据可视化
#
# 使用Plotly创建交互式性能图表：

# %%
# 创建性能图表
try:
    import plotly.graph_objects as go
    from jupyter_integration import create_performance_chart
    
    fig = create_performance_chart()
    fig.show()
except ImportError:
    print("❌ plotly未安装，请运行: pip install plotly")
except Exception as e:
    print(f"❌ 图表创建失败: {e}")

# %% [markdown]
# ## 7. 自定义仪表板
#
# 您也可以创建自定义的组合仪表板，整合多个功能：

# %%
# 创建自定义组合仪表板
from IPython.display import HTML, display

custom_dashboard = """
<div style='border: 2px solid #4CAF50; border-radius: 10px; padding: 20px; background: linear-gradient(135deg, #e3f2fd 0%, #f3e5f5 100%);'>
    <h2 style='color: #1976d2; text-align: center; margin-bottom: 20px;'>🧠 脑启发AI系统 - 综合控制中心</h2>
    
    <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 20px;'>
        <div style='background: rgba(255,255,255,0.9); padding: 15px; border-radius: 8px; box-shadow: 0 2px 8px rgba(0,0,0,0.1);'>
            <h3 style='color: #333; margin-bottom: 10px;'>🎯 快速操作</h3>
            <button onclick="alert('开始训练新的模型')" style='width: 100%; padding: 10px; margin: 5px 0; background: #4CAF50; color: white; border: none; border-radius: 5px; cursor: pointer;'>开始训练</button>
            <button onclick="alert('暂停当前训练')" style='width: 100%; padding: 10px; margin: 5px 0; background: #FF9800; color: white; border: none; border-radius: 5px; cursor: pointer;'>暂停训练</button>
            <button onclick="alert('查看详细报告')" style='width: 100%; padding: 10px; margin: 5px 0; background: #2196F3; color: white; border: none; border-radius: 5px; cursor: pointer;'>生成报告</button>
        </div>
        
        <div style='background: rgba(255,255,255,0.9); padding: 15px; border-radius: 8px; box-shadow: 0 2px 8px rgba(0,0,0,0.1);'>
            <h3 style='color: #333; margin-bottom: 10px;'>📊 关键指标</h3>
            <div style='margin: 10px 0; padding: 10px; background: #f5f5f5; border-radius: 5px;'>
                <strong>系统状态:</strong> <span style='color: #4CAF50;'>● 正常运行</span>
            </div>
            <div style='margin: 10px 0; padding: 10px; background: #f5f5f5; border-radius: 5px;'>
                <strong>活跃模型:</strong> 3个
            </div>
            <div style='margin: 10px 0; padding: 10px; background: #f5f5f5; border-radius: 5px;'>
                <strong>今日训练:</strong> 2小时32分钟
            </div>
        </div>
    </div>
    
    <div style='margin-top: 20px; text-align: center; color: #666; font-size: 14px;'>
        💡 提示: 点击上方按钮执行相应操作，或使用其他单元格中的详细界面
    </div>
</div>
"""

display(HTML(custom_dashboard))

# %% [markdown]
# ## 8. 使用说明和技巧
#
# ### 最佳实践
# - **实时监控**: 使用仪表板定期检查系统状态
# - **训练管理**: 利用训练控制台优化模型性能
# - **性能调优**: 结合监控数据调整参数
# - **定期报告**: 生成性能报告进行分析
#
# ### 故障排除
# - 如果界面显示异常，请刷新页面
# - 确保所有依赖库都已正确安装
# - 检查网络连接（对于实时数据更新）
#
# ### 扩展功能
# - 自定义监控指标
# - 添加新的可视化组件
# - 集成外部数据源
# - 导出数据和报告

# %%
# 显示使用帮助
help_text = """
🧠 脑启发AI系统界面使用帮助
=================================

可用函数:
• show_brain_dashboard() - 显示系统概览仪表板
• show_training_console() - 显示训练控制台
• show_performance_dashboard() - 显示性能监控
• show_system_diagram() - 显示系统架构图
• create_brain_monitor_widget() - 创建监控小部件
• create_training_widget() - 创建训练小部件
• create_performance_chart() - 创建性能图表

提示:
• 所有界面都支持实时数据更新
• 可以组合使用多个界面组件
• 使用 widgets 获得更好的交互体验
• 查看官方文档了解更多功能
"""

print(help_text)

# %% [markdown]
# ## 总结
#
# 您已经成功学习了如何使用脑启发AI系统的用户界面！
#
# ### 学到的内容
# - ✅ 系统概览和实时监控
# - ✅ 交互式训练控制
# - ✅ 性能监控和分析
# - ✅ 系统架构可视化
# - ✅ Jupyter集成使用
#
# ### 下一步
# - 尝试调整训练参数
# - 监控系统性能变化
# - 探索自定义仪表板
# - 集成到您的工作流中
#
# **🎉 恭喜！您现在可以充分利用脑启发AI系统的强大界面功能了！**
